# %%
import pandas as pd

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Name':[ 'Monika' ,' Prathibha' , 'Devika' ] , 'About' :[ ' Doctor life' , 'Enginerr life' , 'enginerring life' ]})
# Out:
#          Name             About
# 0      Monika       Doctor life
# 1   Prathibha     Enginerr life
# 2      Devika  enginerring life

# %%
pd.DataFrame({'Name':['Navya' , 'Prathibha' ,'monika'] , 'school':['MABL','LAS','NHS']}, index=['Student1','Student2','Student3'])
# Out:
#                Name school
# Student1      Navya   MABL
# Student2  Prathibha    LAS
# Student3     monika    NHS

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([ 30,65,65], index=['2014 sales','2015 sales','2017 sales'], name='product')
# Out:
# 2014 sales    30
# 2015 sales    65
# 2017 sales    65
# Name: product, dtype: int64

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %%
# 1D data structure 
# Series cant handle multiple data types
# (values , index, data type)
# Convert list/tuple to create a series

# %%
pd.Series(['2015 sales'])
# Out:
# 0    2015 sales
# dtype: object

# %%
sr1= pd.Series([10,20,30,40,50])
sr1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
sr1[4]
# Out:
# np.int64(50)

# %%
sr1= pd.Series([10,20,30,40,50] , index=['a','b','c','d','e'],dtype= float)
sr1
# Out:
# a    10.0
# b    20.0
# c    30.0
# d    40.0
# e    50.0
# dtype: float64

# %%
# DataFrame creation and manipulation

# %%
# 2D data structure (table)
# data frame is created by combining multiple columns
# each column should have its own data type (single data type)
# each column can be list/tuple/Series/1D array

# %%
dict1=  {
    'col1' : [1,2,3],
    'col2' :pd.Series(['a','b','c'])
}
df1=pd.DataFrame(dict1)
df1
# Out:
#    col1 col2
# 0     1    a
# 1     2    b
# 2     3    c

# %%
df1.dtypes
# Out:
# col1     int64
# col2    object
# dtype: object

# %%
df1=pd.DataFrame({'id' :[2,3,4,5,6], 'stat_marks': [53,98,88,96,69]})
df2=pd.DataFrame({'id' :[2,3,4,5,6], 'ml_marks': [93,88,78,100,99]})
pd.concat([df1, df2])
# Out:
#    id  stat_marks  ml_marks
# 0   2        53.0       NaN
# 1   3        98.0       NaN
# 2   4        88.0       NaN
# 3   5        96.0       NaN
# 4   6        69.0       NaN
# 0   2         NaN      93.0
# 1   3         NaN      88.0
# 2   4         NaN      78.0
# 3   5         NaN     100.0
# 4   6         NaN      99.0

# %%
df3 =pd.concat([df1, df2])
df3
# Out:
#    id  stat_marks  ml_marks
# 0   2        53.0       NaN
# 1   3        98.0       NaN
# 2   4        88.0       NaN
# 3   5        96.0       NaN
# 4   6        69.0       NaN
# 0   2         NaN      93.0
# 1   3         NaN      88.0
# 2   4         NaN      78.0
# 3   5         NaN     100.0
# 4   6         NaN      99.0

# %%
df3.reset_index()# by default reset_index will store old index in a new column
# Out:
#    index  id  stat_marks  ml_marks
# 0      0   2        53.0       NaN
# 1      1   3        98.0       NaN
# 2      2   4        88.0       NaN
# 3      3   5        96.0       NaN
# 4      4   6        69.0       NaN
# 5      0   2         NaN      93.0
# 6      1   3         NaN      88.0
# 7      2   4         NaN      78.0
# 8      3   5         NaN     100.0
# 9      4   6         NaN      99.0

# %%
df3.reset_index(drop = True) # drop = True --> old index wont be saved
# by default changes wont be saved in df3
# Out:
#    id  stat_marks  ml_marks
# 0   2        53.0       NaN
# 1   3        98.0       NaN
# 2   4        88.0       NaN
# 3   5        96.0       NaN
# 4   6        69.0       NaN
# 5   2         NaN      93.0
# 6   3         NaN      88.0
# 7   4         NaN      78.0
# 8   5         NaN     100.0
# 9   6         NaN      99.0

# %%
#select * from df1 join df2 on df1.id = df2.id

# %% [markdown]
# df1.merge(df2 , on ='id' , how='left')

# %%
df1.merge(df2 , on ='id' , how='left')
# Out:
#    id  stat_marks  ml_marks
# 0   2          53        93
# 1   3          98        88
# 2   4          88        78
# 3   5          96       100
# 4   6          69        99

# %%
df1.merge(df2 , on ='id' , how='right')
# Out:
#    id  stat_marks  ml_marks
# 0   2          53        93
# 1   3          98        88
# 2   4          88        78
# 3   5          96       100
# 4   6          69        99

# %%
df1.merge(df2 , on ='id' , how='outer')
# Out:
#    id  stat_marks  ml_marks
# 0   2          53        93
# 1   3          98        88
# 2   4          88        78
# 3   5          96       100
# 4   6          69        99

# %%
df1.merge(df2 , on ='id' , how='inner')
# Out:
#    id  stat_marks  ml_marks
# 0   2          53        93
# 1   3          98        88
# 2   4          88        78
# 3   5          96       100
# 4   6          69        99

# %%
df1
# Out:
#    id  stat_marks
# 0   2          53
# 1   3          98
# 2   4          88
# 3   5          96
# 4   6          69

# %%
df2
# Out:
#    id  ml_marks
# 0   2        93
# 1   3        88
# 2   4        78
# 3   5       100
# 4   6        99

# %%
pd.concat([df1, df2])
# Out:
#    id  stat_marks  ml_marks
# 0   2        53.0       NaN
# 1   3        98.0       NaN
# 2   4        88.0       NaN
# 3   5        96.0       NaN
# 4   6        69.0       NaN
# 0   2         NaN      93.0
# 1   3         NaN      88.0
# 2   4         NaN      78.0
# 3   5         NaN     100.0
# 4   6         NaN      99.0

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Admin\\prathu'

# %%
# Note: df4 will be defined later when reading from CSV
# Using df1 here as an example instead
df1.head()
# Out:
#    id  stat_marks
# 0   2          53
# 1   3          98
# 2   4          88
# 3   5          96
# 4   6          69

# %%
import pandas as pd

df1 = pd.DataFrame({'id':[1,2,3,4,5], 'stats_marks': [94,85,73,96,99]})
df2 = pd.DataFrame({'id':[7,8,9,10,11], 'ml_marks':[80,86,76,94,100]})

# %%
df1
# Out:
#    id  stats_marks
# 0   1           94
# 1   2           85
# 2   3           73
# 3   4           96
# 4   5           99

# %%
pd.concat([df1,df2])
# Out:
#    id  stats_marks  ml_marks
# 0   1         94.0       NaN
# 1   2         85.0       NaN
# 2   3         73.0       NaN
# 3   4         96.0       NaN
# 4   5         99.0       NaN
# 0   7          NaN      80.0
# 1   8          NaN      86.0
# 2   9          NaN      76.0
# 3  10          NaN      94.0
# 4  11          NaN     100.0

# %%
import pandas as pd

df4 = pd.DataFrame({'id':[1,2,3,4,5], 'stats_marks': [94,85,73,96,99]})
df5 = pd.DataFrame({'id':[7,8,9,10,11], 'stats_marks':[80,86,76,94,100]})
df6 = pd.concat([df4,df5])
df6
# Out:
#    id  stats_marks
# 0   1           94
# 1   2           85
# 2   3           73
# 3   4           96
# 4   5           99
# 0   7           80
# 1   8           86
# 2   9           76
# 3  10           94
# 4  11          100

# %%
df1 = pd.DataFrame({'id': [1,2,3,4,5], 'stats_marks': [94,95,99,92,94]})
df2 = pd.DataFrame({'sno': [6,7,8,9,10], 'ml_marks': [93,97,94,90,88]})
df2
# Out:
#    sno  ml_marks
# 0    6        93
# 1    7        97
# 2    8        94
# 3    9        90
# 4   10        88

# %%
df1.join(df2)
# Out:
#    id  stats_marks  sno  ml_marks
# 0   1           94    6        93
# 1   2           95    7        97
# 2   3           99    8        94
# 3   4           92    9        90
# 4   5           94   10        88

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Admin\\prathu'

# %%
df1 = pd.read_csv('Auto.csv') # r - read/raw strings
df1.head() # top 5 observations by default 
# rows/ observations/ records/ data points
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
# 2   NaN        8.0         318.0         150    3436          11.0    70
# 3   NaN        8.0           NaN         150    3433          12.0    70
# 4   NaN        8.0           NaN         140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
import pandas as pd
df4 = pd.read_csv('Auto.csv')
df4
# Out:
#       mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0    18.0        8.0         307.0         130    3504          12.0    70
# 1    15.0        8.0         350.0         165    3693          11.5    70
# 2     NaN        8.0         318.0         150    3436          11.0    70
# 3     NaN        8.0           NaN         150    3433          12.0    70
# 4     NaN        8.0           NaN         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0        4.0         140.0          86    2790          15.6    82
# 393  44.0        4.0          97.0          52    2130          24.6    82
# 394  32.0        4.0         135.0          84    2295          11.6    82
# 395  28.0        4.0         120.0          79    2625          18.6    82
# 396  31.0        4.0         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
# pd.read_csv --> Auto.csv # function and filename extension should match
# pd.read_excel ---> .xlsx

# %%
df4.head(10)
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
# 2   NaN        8.0         318.0         150    3436          11.0    70
# 3   NaN        8.0           NaN         150    3433          12.0    70
# 4   NaN        8.0           NaN         140    3449          10.5    70
# 5   NaN        8.0           NaN         198    4341          10.0    70
# 6   NaN        8.0           NaN         220    4354           9.0    70
# 7  14.0        8.0           NaN         215    4312           8.5    70
# 8  14.0        8.0         455.0         225    4425          10.0    70
# 9  15.0        8.0         390.0         190    3850           8.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# ...

# %%
df4.head(2)
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320

# %%
df4.tail()
# Out:
#       mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 392  27.0        4.0         140.0          86    2790          15.6    82
# 393  44.0        4.0          97.0          52    2130          24.6    82
# 394  32.0        4.0         135.0          84    2295          11.6    82
# 395  28.0        4.0         120.0          79    2625          18.6    82
# 396  31.0        4.0         119.0          82    2720          19.4    82
#
#      origin             name
# 392       1  ford mustang gl
# 393       2        vw pickup
# 394       1    dodge rampage
# 395       1      ford ranger
# 396       1       chevy s-10

# %%
df4.shape
# Out:
# (397, 9)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     394 non-null    float64
#  2   displacement  392 non-null    float64
#  3   Horse Power   397 non-null    object
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.0+ KB

# %%
df4.describe() # will execute only on int/float columns
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  392.000000  394.000000    392.000000   397.000000    397.000000
# mean    23.611735    5.439086    191.080357  2970.261965     15.555668
# std      7.827466    1.693452    102.452019   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    100.750000  2223.000000     13.800000
# 50%     23.000000    4.000000    145.500000  2800.000000     15.500000
# 75%     29.000000    8.000000    260.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df4['mpg']
# Out:
# 0      18.0
# 1      15.0
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 392    27.0
# 393    44.0
# 394    32.0
# 395    28.0
# 396    31.0
# Name: mpg, Length: 397, dtype: float64

# %%
# if you want to extract more than one column --> use second bracket
df4[['mpg','cylinders','acceleration']]
# Out:
#       mpg  cylinders  acceleration
# 0    18.0        8.0          12.0
# 1    15.0        8.0          11.5
# 2     NaN        8.0          11.0
# 3     NaN        8.0          12.0
# 4     NaN        8.0          10.5
# ..    ...        ...           ...
# 392  27.0        4.0          15.6
# 393  44.0        4.0          24.6
# 394  32.0        4.0          11.6
# 395  28.0        4.0          18.6
# 396  31.0        4.0          19.4
#
# [397 rows x 3 columns]

# %%
# %pwd
# Out:
# 'C:\\Users\\Admin\\prathu'

# %%
######DATA Cleaning

# %%
#df4= pd.read_csv(r'C:\\Users\\Admin\\prathu') #r' is for reading strings
#df4

# %%
df4['mpg'].mean()
# Out:
# np.float64(23.611734693877548)

# %%
df4[['mpg', 'cylinders', 'acceleration']].min()
# Out:
# mpg             9.0
# cylinders       3.0
# acceleration    8.0
# dtype: float64

# %%
#astype int<---> float type , convert to any string
#pd.to_numeric :object_>int

# %%
df4.head() # preveiw to dataset
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
# 2   NaN        8.0         318.0         150    3436          11.0    70
# 3   NaN        8.0           NaN         150    3433          12.0    70
# 4   NaN        8.0           NaN         140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df4['acceleration'].astype(int)
# Out:
# 0      12
# 1      11
# 2      11
# 3      12
# 4      10
#        ..
# 392    15
# 393    24
# 394    11
# 395    18
# 396    19
# Name: acceleration, Length: 397, dtype: int64

# %%
#this is how convertion of string to int is done using astype() funtion

# %%
 # df4['Horse Power'].astype(int)

# %%
df4.head()
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
# 2   NaN        8.0         318.0         150    3436          11.0    70
# 3   NaN        8.0           NaN         150    3433          12.0    70
# 4   NaN        8.0           NaN         140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# Removed problematic nested loop that created excessive output
# To add weights and acceleration: df4['weight'] + df4['acceleration']

# %%
df4['col1']= df4['acceleration'] + df4['weight']

# %%
df4.head()
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
# 2   NaN        8.0         318.0         150    3436          11.0    70
# 3   NaN        8.0           NaN         150    3433          12.0    70
# 4   NaN        8.0           NaN         140    3449          10.5    70
#
#    origin                       name    col1
# 0       1  chevrolet chevelle malibu  3516.0
# 1       1          buick skylark 320  3704.5
# 2       1         plymouth satellite  3447.0
# 3       1              amc rebel sst  3445.0
# 4       1                ford torino  3459.5

# %%
df4['col2'] = df4['acceleration']**2

# %%
df4.head()
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
# 2   NaN        8.0         318.0         150    3436          11.0    70
# 3   NaN        8.0           NaN         150    3433          12.0    70
# 4   NaN        8.0           NaN         140    3449          10.5    70
#
#    origin                       name    col1    col2
# 0       1  chevrolet chevelle malibu  3516.0  144.00
# 1       1          buick skylark 320  3704.5  132.25
# 2       1         plymouth satellite  3447.0  121.00
# 3       1              amc rebel sst  3445.0  144.00
# 4       1                ford torino  3459.5  110.25

# %%
df4['col2'] = df4['acceleration'] +20 # in brackets if old name was given data will be replaced
df4.head()
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
# 2   NaN        8.0         318.0         150    3436          11.0    70
# 3   NaN        8.0           NaN         150    3433          12.0    70
# 4   NaN        8.0           NaN         140    3449          10.5    70
#
#    origin                       name    col1  col2
# 0       1  chevrolet chevelle malibu  3516.0  32.0
# 1       1          buick skylark 320  3704.5  31.5
# 2       1         plymouth satellite  3447.0  31.0
# 3       1              amc rebel sst  3445.0  32.0
# 4       1                ford torino  3459.5  30.5

# %%
int('20') # valid conversion
# Out:
# 20

# %%
#int('a') # this cannot be done

# %%
import numpy as np
np.array([1,2,3,4,5,6])
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
pd.to_numeric(df4['Horse Power'], errors='coerce')
#errors = coerce---> when encountered error skip them by converting them into blanks
#? --> null.blanks/empty
# Out:
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
#        ...
# 392     86.0
# 393     52.0
# 394     84.0
# 395     79.0
# 396     82.0
# Name: Horse Power, Length: 397, dtype: float64

# %%
df4.isna().sum()
# Out:
# mpg             5
# cylinders       3
# displacement    5
# Horse Power     0
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# col1            0
# col2            0
# dtype: int64

# %%
df4['Horse Power']=pd.to_numeric(df4['Horse Power'], errors='coerce')
#errors = coerce---> when encountered error skip them by convererting them into blanks

# %%
df4.isna().sum() # after ci=onversion 5 '?' replaced  with null
# Out:
# mpg             5
# cylinders       3
# displacement    5
# Horse Power     5
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# col1            0
# col2            0
# dtype: int64

# %%
##handling null values

# %%
#1. Drop the rows where i have blanks
#2. replace null values with mean/medians/mode --->statistical values

# %%
df4.head()
# Out:
#     mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0        130.0    3504          12.0    70
# 1  15.0        8.0         350.0        165.0    3693          11.5    70
# 2   NaN        8.0         318.0        150.0    3436          11.0    70
# 3   NaN        8.0           NaN        150.0    3433          12.0    70
# 4   NaN        8.0           NaN        140.0    3449          10.5    70
#
#    origin                       name    col1  col2
# 0       1  chevrolet chevelle malibu  3516.0  32.0
# 1       1          buick skylark 320  3704.5  31.5
# 2       1         plymouth satellite  3447.0  31.0
# 3       1              amc rebel sst  3445.0  32.0
# 4       1                ford torino  3459.5  30.5

# %%
df4.head(10)
# Out:
#     mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0        130.0    3504          12.0    70
# 1  15.0        8.0         350.0        165.0    3693          11.5    70
# 2   NaN        8.0         318.0        150.0    3436          11.0    70
# 3   NaN        8.0           NaN        150.0    3433          12.0    70
# 4   NaN        8.0           NaN        140.0    3449          10.5    70
# 5   NaN        8.0           NaN        198.0    4341          10.0    70
# 6   NaN        8.0           NaN        220.0    4354           9.0    70
# 7  14.0        8.0           NaN        215.0    4312           8.5    70
# 8  14.0        8.0         455.0        225.0    4425          10.0    70
# 9  15.0        8.0         390.0        190.0    3850           8.5    70
#
#    origin                       name    col1  col2
# 0       1  chevrolet chevelle malibu  3516.0  32.0
# 1       1          buick skylark 320  3704.5  31.5
# ...

# %%
df4.head()
# Out:
#     mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0        130.0    3504          12.0    70
# 1  15.0        8.0         350.0        165.0    3693          11.5    70
# 2   NaN        8.0         318.0        150.0    3436          11.0    70
# 3   NaN        8.0           NaN        150.0    3433          12.0    70
# 4   NaN        8.0           NaN        140.0    3449          10.5    70
#
#    origin                       name    col1  col2
# 0       1  chevrolet chevelle malibu  3516.0  32.0
# 1       1          buick skylark 320  3704.5  31.5
# 2       1         plymouth satellite  3447.0  31.0
# 3       1              amc rebel sst  3445.0  32.0
# 4       1                ford torino  3459.5  30.5

# %%
df4.dropna() #changes are not saved in df4
# Out:
#       mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 0    18.0        8.0         307.0        130.0    3504          12.0    70
# 1    15.0        8.0         350.0        165.0    3693          11.5    70
# 8    14.0        8.0         455.0        225.0    4425          10.0    70
# 9    15.0        8.0         390.0        190.0    3850           8.5    70
# 10   15.0        8.0         383.0        170.0    3563          10.0    70
# ..    ...        ...           ...          ...     ...           ...   ...
# 392  27.0        4.0         140.0         86.0    2790          15.6    82
# 393  44.0        4.0          97.0         52.0    2130          24.6    82
# 394  32.0        4.0         135.0         84.0    2295          11.6    82
# 395  28.0        4.0         120.0         79.0    2625          18.6    82
# 396  31.0        4.0         119.0         82.0    2720          19.4    82
#
#      origin                       name    col1  col2
# ...

# %%
383/397
# Out:
# 0.964735516372796

# %%
df4.shape
# Out:
# (397, 11)

# %%
df4=df4.dropna()

# %%
df4
# Out:
#       mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 0    18.0        8.0         307.0        130.0    3504          12.0    70
# 1    15.0        8.0         350.0        165.0    3693          11.5    70
# 8    14.0        8.0         455.0        225.0    4425          10.0    70
# 9    15.0        8.0         390.0        190.0    3850           8.5    70
# 10   15.0        8.0         383.0        170.0    3563          10.0    70
# ..    ...        ...           ...          ...     ...           ...   ...
# 392  27.0        4.0         140.0         86.0    2790          15.6    82
# 393  44.0        4.0          97.0         52.0    2130          24.6    82
# 394  32.0        4.0         135.0         84.0    2295          11.6    82
# 395  28.0        4.0         120.0         79.0    2625          18.6    82
# 396  31.0        4.0         119.0         82.0    2720          19.4    82
#
#      origin                       name    col1  col2
# ...

# %%
df4.shape
# Out:
# (383, 11)

# %%
df4=df4.dropna()

# %%
df4.dropna(inplace= True)

# %%
df4.shape
# Out:
# (383, 11)

# %%
df4.head(383)
# Out:
#       mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 0    18.0        8.0         307.0        130.0    3504          12.0    70
# 1    15.0        8.0         350.0        165.0    3693          11.5    70
# 8    14.0        8.0         455.0        225.0    4425          10.0    70
# 9    15.0        8.0         390.0        190.0    3850           8.5    70
# 10   15.0        8.0         383.0        170.0    3563          10.0    70
# ..    ...        ...           ...          ...     ...           ...   ...
# 392  27.0        4.0         140.0         86.0    2790          15.6    82
# 393  44.0        4.0          97.0         52.0    2130          24.6    82
# 394  32.0        4.0         135.0         84.0    2295          11.6    82
# 395  28.0        4.0         120.0         79.0    2625          18.6    82
# 396  31.0        4.0         119.0         82.0    2720          19.4    82
#
#      origin                       name    col1  col2
# ...

# %%
df4.head(19)
# Out:
#      mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 0   18.0        8.0         307.0        130.0    3504          12.0    70
# 1   15.0        8.0         350.0        165.0    3693          11.5    70
# 8   14.0        8.0         455.0        225.0    4425          10.0    70
# 9   15.0        8.0         390.0        190.0    3850           8.5    70
# 10  15.0        8.0         383.0        170.0    3563          10.0    70
# 14  24.0        4.0         113.0         95.0    2372          15.0    70
# 15  22.0        6.0         198.0         95.0    2833          15.5    70
# 16  18.0        6.0         199.0         97.0    2774          15.5    70
# 17  21.0        6.0         200.0         85.0    2587          16.0    70
# 18  27.0        4.0          97.0         88.0    2130          14.5    70
# 19  26.0        4.0          97.0         46.0    1835          20.5    70
# ...

# %%
df4.dropna()
# Out:
#       mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 0    18.0        8.0         307.0        130.0    3504          12.0    70
# 1    15.0        8.0         350.0        165.0    3693          11.5    70
# 8    14.0        8.0         455.0        225.0    4425          10.0    70
# 9    15.0        8.0         390.0        190.0    3850           8.5    70
# 10   15.0        8.0         383.0        170.0    3563          10.0    70
# ..    ...        ...           ...          ...     ...           ...   ...
# 392  27.0        4.0         140.0         86.0    2790          15.6    82
# 393  44.0        4.0          97.0         52.0    2130          24.6    82
# 394  32.0        4.0         135.0         84.0    2295          11.6    82
# 395  28.0        4.0         120.0         79.0    2625          18.6    82
# 396  31.0        4.0         119.0         82.0    2720          19.4    82
#
#      origin                       name    col1  col2
# ...

# %%
df4.drop('col2',axis = 1,inplace = True) # axis = 1 --> for columns # drop/delete col3 from df1
df4.head(2)
# Out:
#     mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0        130.0    3504          12.0    70
# 1  15.0        8.0         350.0        165.0    3693          11.5    70
#
#    origin                       name    col1
# 0       1  chevrolet chevelle malibu  3516.0
# 1       1          buick skylark 320  3704.5

# %%
#data manipulation

# %%
df4.head(10)
# Out:
#      mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 0   18.0        8.0         307.0        130.0    3504          12.0    70
# 1   15.0        8.0         350.0        165.0    3693          11.5    70
# 8   14.0        8.0         455.0        225.0    4425          10.0    70
# 9   15.0        8.0         390.0        190.0    3850           8.5    70
# 10  15.0        8.0         383.0        170.0    3563          10.0    70
# 14  24.0        4.0         113.0         95.0    2372          15.0    70
# 15  22.0        6.0         198.0         95.0    2833          15.5    70
# 16  18.0        6.0         199.0         97.0    2774          15.5    70
# 17  21.0        6.0         200.0         85.0    2587          16.0    70
# 18  27.0        4.0          97.0         88.0    2130          14.5    70
#
#     origin                       name    col1
# 0        1  chevrolet chevelle malibu  3516.0
# 1        1          buick skylark 320  3704.5
# ...

# %%
df4.iloc[1:9 , 3:6]
# Out:
#     Horse Power  weight  acceleration
# 1         165.0    3693          11.5
# 8         225.0    4425          10.0
# 9         190.0    3850           8.5
# 10        170.0    3563          10.0
# 14         95.0    2372          15.0
# 15         95.0    2833          15.5
# 16         97.0    2774          15.5
# 17         85.0    2587          16.0

# %%
## loc
# we need to give names instead of index numbers
# End value is included/

# %%
df4.loc[1:8, 'Horse Power':'acceleration']
# Out:
#    Horse Power  weight  acceleration
# 1        165.0    3693          11.5
# 8        225.0    4425          10.0

# %%
### applying a function

# %%
def sqr_num(num):
    return num**2

# %%
df4['acceleration'].apply(sqr_num)
# Out:
# 0      144.00
# 1      132.25
# 8      100.00
# 9       72.25
# 10     100.00
#         ...
# 392    243.36
# 393    605.16
# 394    134.56
# 395    345.96
# 396    376.36
# Name: acceleration, Length: 383, dtype: float64

# %%
def evn_odd(num):
    if num %2==0:
        return 'even'
    else:
        return 'odd'

# %%
df4['col1'] = df4['acceleration'].apply(evn_odd)
df4.head(3)
# Out:
#     mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0        130.0    3504          12.0    70
# 1  15.0        8.0         350.0        165.0    3693          11.5    70
# 8  14.0        8.0         455.0        225.0    4425          10.0    70
#
#    origin                       name  col1
# 0       1  chevrolet chevelle malibu  even
# 1       1          buick skylark 320   odd
# 8       1           pontiac catalina  even

# %%
df4['col1'] =  df4['acceleration'].apply(lambda num: num**2)
df4['col2'] =  df4['acceleration'].apply(lambda num: 'Even' if num%2 ==0 else 'Odd')
df4.head()
# Out:
#      mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 0   18.0        8.0         307.0        130.0    3504          12.0    70
# 1   15.0        8.0         350.0        165.0    3693          11.5    70
# 8   14.0        8.0         455.0        225.0    4425          10.0    70
# 9   15.0        8.0         390.0        190.0    3850           8.5    70
# 10  15.0        8.0         383.0        170.0    3563          10.0    70
#
#     origin                       name    col1  col2
# 0        1  chevrolet chevelle malibu  144.00  Even
# 1        1          buick skylark 320  132.25   Odd
# 8        1           pontiac catalina  100.00  Even
# 9        1         amc ambassador dpl   72.25   Odd
# 10       1        dodge challenger se  100.00  Even

# %%
df4.sort_values(by = 'mpg', ascending=False)
# ascending = True --> for ascending order
# Out:
#       mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 322  46.6        4.0          86.0         65.0    2110          17.9    80
# 329  44.6        4.0          91.0         67.0    1850          13.8    80
# 325  44.3        4.0          90.0         48.0    2085          21.7    80
# 393  44.0        4.0          97.0         52.0    2130          24.6    82
# 326  43.4        4.0          90.0         48.0    2335          23.7    80
# ..    ...        ...           ...          ...     ...           ...   ...
# 27   11.0        8.0         318.0        210.0    4382          13.5    70
# 67   11.0        8.0         429.0        208.0    4633          11.0    72
# 25   10.0        8.0         360.0        215.0    4615          14.0    70
# 26   10.0        8.0         307.0        200.0    4376          15.0    70
# 28    9.0        8.0         304.0        193.0    4732          18.5    70
#
#      origin                  name    col1  col2
# ...

# %%
# conditional formating
# extract records where mpg value is greater than 40

# %%
cond1 = df4['mpg'] > 40 # Relational operators ouput will always be boolean # <,>, <=, >= , ==, !=
cond1
# Out:
# 0      False
# 1      False
# 8      False
# 9      False
# 10     False
#        ...
# 392    False
# 393     True
# 394    False
# 395    False
# 396    False
# Name: mpg, Length: 383, dtype: bool

# %%
df4[cond1]
# Out:
#       mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 244  43.1        4.0          90.0         48.0    1985          21.5    78
# 309  41.5        4.0          98.0         76.0    2144          14.7    80
# 322  46.6        4.0          86.0         65.0    2110          17.9    80
# 324  40.8        4.0          85.0         65.0    2110          19.2    80
# 325  44.3        4.0          90.0         48.0    2085          21.7    80
# 326  43.4        4.0          90.0         48.0    2335          23.7    80
# 329  44.6        4.0          91.0         67.0    1850          13.8    80
# 393  44.0        4.0          97.0         52.0    2130          24.6    82
#
#      origin                             name    col1 col2
# 244       2  volkswagen rabbit custom diesel  462.25  Odd
# 309       2                        vw rabbit  216.09  Odd
# 322       3                        mazda glc  320.41  Odd
# ...

# %%
cond2 = (df4['mpg'] > 40) & (df4['origin'] == 3)
cond2
# Out:
# 0      False
# 1      False
# 8      False
# 9      False
# 10     False
#        ...
# 392    False
# 393    False
# 394    False
# 395    False
# 396    False
# Length: 383, dtype: bool

# %%
df4[cond2]
# Out:
#       mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 322  46.6        4.0          86.0         65.0    2110          17.9    80
# 324  40.8        4.0          85.0         65.0    2110          19.2    80
# 329  44.6        4.0          91.0         67.0    1850          13.8    80
#
#      origin                 name    col1 col2
# 322       3            mazda glc  320.41  Odd
# 324       3           datsun 210  368.64  Odd
# 329       3  honda civic 1500 gl  190.44  Odd

# %%
df4[(df4['mpg'] > 40) & (df4['origin'] == 3)] # reality
# Out:
#       mpg  cylinders  displacement  Horse Power  weight  acceleration  year  \
# 322  46.6        4.0          86.0         65.0    2110          17.9    80
# 324  40.8        4.0          85.0         65.0    2110          19.2    80
# 329  44.6        4.0          91.0         67.0    1850          13.8    80
#
#      origin                 name    col1 col2
# 322       3            mazda glc  320.41  Odd
# 324       3           datsun 210  368.64  Odd
# 329       3  honda civic 1500 gl  190.44  Odd
