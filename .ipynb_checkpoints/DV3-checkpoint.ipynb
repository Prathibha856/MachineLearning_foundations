# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('Auto.csv')

# %%
df1
# Out:
#       mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0    18.0        8.0         307.0         130    3504          12.0    70
# 1    15.0        8.0         350.0         165    3693          11.5    70
# 2     NaN        8.0         318.0         150    3436          11.0    70
# 3     NaN        8.0           NaN         150    3433          12.0    70
# 4     NaN        8.0           NaN         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0        4.0         140.0          86    2790          15.6    82
# 393  44.0        4.0          97.0          52    2130          24.6    82
# 394  32.0        4.0         135.0          84    2295          11.6    82
# 395  28.0        4.0         120.0          79    2625          18.6    82
# 396  31.0        4.0         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
df1[['mpg','weight','acceleration']].corr()# correlation (stats concepts)
# Correlation gives mathematical (numerical) representation of relation between columns
# Out:
#                    mpg    weight  acceleration
# mpg           1.000000 -0.830273      0.410981
# weight       -0.830273  1.000000     -0.419502
# acceleration  0.410981 -0.419502      1.000000

# %%
plt.scatter(df1['mpg'],df1['acceleration'])

# %%
plt.scatter(df1['mpg'],df1['acceleration'] , df1['weight'])

# %%
###SEABORN

# %%
# advanced data visualisation
# Reporting / presentation

# %%
sns.heatmap(df1[['mpg','acceleration','displacement','weight']].corr())
# Out:
# <Axes: >

# %%
sns.heatmap(df1[['mpg','cylinders','displacement','weight','acceleration']])
# Out:
# <Axes: >

# %%
sns.heatmap(df1[['mpg','acceleration','displacement','weight']].corr())
# Out:
# <Axes: >

# %%
sns.heatmap(df1[['mpg','displacement','acceleration','weight']].corr(),annot = True , cmap='Set2') # more creative , annot
#gives values in the partciluar block and cmap is for set coloring
# Out:
# <Axes: >

# %%
sns.heatmap(df1[['mpg','displacement','acceleration','weight']].corr(),annot = True , cmap='Paired') # more creative , annot
#gives values in the partciluar block and cmap is for set coloring
# Out:
# <Axes: >

# %%
sns.heatmap(df1[['mpg','displacement','acceleration','weight']].corr(),annot = True , cmap='Blues') # more creative , annot
#gives values in the partciluar block and cmap is for set coloring
# Out:
# <Axes: >

# %%
sns.pairplot(df1[['mpg','acceleration','weight']])

# %%
sns.countplot(x ='origin', data= df1)
# Out:
# <Axes: xlabel='origin', ylabel='count'>

# %%
sns.countplot(x ='origin', data= df1 ,hue='cylinders')
# Out:
# <Axes: xlabel='origin', ylabel='count'>

# %%
df1[['origin','cylinders']].value_counts()
# Out:
# origin  cylinders
# 1       8.0          100
#         6.0           74
#         4.0           71
# 3       4.0           69
# 2       4.0           63
# 3       6.0            6
#         3.0            4
# 2       6.0            4
#         5.0            3
# Name: count, dtype: int64

# %%
df1[(df1['origin'] ==1) & (df1['cylinders'] == 6)]
# Out:
#       mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 15   22.0        6.0         198.0          95    2833          15.5    70
# 16   18.0        6.0         199.0          97    2774          15.5    70
# 17   21.0        6.0         200.0          85    2587          16.0    70
# 24   21.0        6.0         199.0          90    2648          15.0    70
# 33   19.0        6.0         232.0         100    2634          13.0    71
# ..    ...        ...           ...         ...     ...           ...   ...
# 365  20.2        6.0         200.0          88    3060          17.1    81
# 366  17.6        6.0         225.0          85    3465          16.6    81
# 385  25.0        6.0         181.0         110    2945          16.4    82
# 386  38.0        6.0         262.0          85    3015          17.0    82
# 388  22.0        6.0         232.0         112    2835          14.7    82
#
#      origin                               name
# ...
