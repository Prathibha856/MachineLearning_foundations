# %%
import numpy # no output will be returned or no error --> Numpy is available (default app)

# %%
import xyz # xyz is a random word --> will always give error ( explanation purpose )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import xyz
#
# ModuleNotFoundError: No module named 'xyz'

# %%
import Numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import Numpy
#
# ModuleNotFoundError: No module named 'Numpy'

# %%
import numppy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import numppy
#
# ModuleNotFoundError: No module named 'numppy'

# %%
# ModuleNotFoundError:
# 1. Case sensitive 
# 2. Spelling mistake
# 3. Install the module from pypi website (assume if its 1 & 2 )

# %%
# If import numpy didnt give you error --> No installation is required

# %%
pip install numpy # this installation is for future purpose if in case you encounter modulenotfound error
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Create an array

# %%
# As arrays are not default to python we need to convert list/tuple into an array

# %%
ar1 = numpy.array([1,2,3,4,5])
ar1
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(ar1) # data structure of ar1
# Out:
# numpy.ndarray

# %%
numpy.array([1,2,3,4,'python'])
# Out:
# array(['1', '2', '3', '4', 'python'], dtype='<U21')

# %%
# even if one string value is available entire array will be converted into strings

# %%
# junior --> senior --> lead --> manager -->> sr manager --> head
# bool --> int --> float --> complex --> string

# %%
numpy.array([1,2,3,4,2.45])
# Out:
# array([1.  , 2.  , 3.  , 4.  , 2.45])

# %%
list1 = [1,2,3,4,5]
[i**2 for i in list1] # need to use a loop to square each elements
# Out:
# [1, 4, 9, 16, 25]

# %%
ar1
# Out:
# array([1, 2, 3, 4, 5])

# %%
ar1 **2 # here no need to use loop to square each element
# Out:
# array([ 1,  4,  9, 16, 25])
